# %% [markdown]
# Q1. What is Lasso Regression, and how does it differ from other regression techniques?

# %% [markdown]
# Ans. Lasso Regression (Least Absolute Shrinkage and Selection Operator)
# Lasso regression is a type of linear regression that incorporates L1 regularization to penalize the absolute values of the regression coefficients. This penalty term encourages sparsity in the model, meaning it can shrink some coefficients to exactly zero, effectively performing feature selection.

# %% [markdown]
# Q2. What is the main advantage of using Lasso Regression in feature selection?

# %% [markdown]
# Ans. The primary advantage of using Lasso Regression for feature selection is its ability to automatically shrink some coefficients to exactly zero, effectively eliminating irrelevant or redundant predictors from the model. This results in a sparse model that is easier to interpret, computationally efficient, and potentially improves predictive performance by reducing overfitting.

# %% [markdown]
# Q3. How do you interpret the coefficients of a Lasso Regression model?

# %% [markdown]
# Nonzero coefficients indicate selected predictors, with sign and magnitude showing the nature and strength of the relationship.
# Zero coefficients imply excluded predictors.
# Interpret coefficients in the context of the chosen
# �
# λ, the scale of predictors, and the presence of multicollinearity.

# %% [markdown]
# Q4. What are the tuning parameters that can be adjusted in Lasso Regression, and how do they affect the
# model's performance?

# %% [markdown]
# Ans. In Lasso Regression, the primary tuning parameter is the regularization parameter (
# �
# λ). Some additional parameters, depending on the implementation (e.g., scikit-learn's Lasso class), can also be adjusted to influence the model’s performance. Here’s a detailed breakdown:

# %% [markdown]
# Q5. Can Lasso Regression be used for non-linear regression problems? If yes, how?

# %% [markdown]
# Ans. Lasso Regression is inherently a linear regression technique, meaning it models the relationship between the predictors and the target as a linear combination of the predictors. However, Lasso Regression can be adapted to handle non-linear relationships using transformations of the predictors or advanced extensions.
